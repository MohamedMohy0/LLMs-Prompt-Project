# %%
import pandas as pd

# %%
train_old=pd.read_excel("train_split_old.xlsx")
train_new=pd.read_excel("train_split_new.xlsx")
test_old=pd.read_excel("test_split_old.xlsx")
test_new=pd.read_excel("train_split_new.xlsx")
dev_old=pd.read_excel("dev_split_old.xlsx")
dev_new=pd.read_excel("dev_split_new.xlsx")

# %%
print(f"The Size for Old train is {len(train_old)} and The New is {len(train_new)}")
print(f"The Size for Old test is {len(test_old)} and The New is {len(test_new)}")
print(f"The Size for Old dev is {len(dev_old)} and The New is {len(dev_new)}")
# Out:
# The Size for Old train is 75976 and The New is 73976
# The Size for Old test is 21105 and The New is 73976
# The Size for Old dev is 8442 and The New is 10569
